# %%
from deepface import DeepFace
import pandas as pd
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
  "GhostFaceNet"
]

# %%
# to put the bounding bo

# %%
def recognizerr(image_path):
    #face recognition
    print(image_path)
    global lst_recognizer
    dfs = DeepFace.find(
      img_path = image_path,
      db_path = "D:/Elecon/face_recognition_attendance_system/sample_data/Ronak/", 
      model_name = models[6],
      detector_backend="retinaface",  # RetinaFace handles angled faces well
      align=True,  # Enable face alignment
      #enforce_detection=False ,  # This will skip face detection
    )
    # Assuming `dfs` contains the results from DeepFace.find()
    # It's a list of DataFrames, with each DataFrame corresponding to a query image
    
    # Loop through each DataFrame in dfs
    for df in dfs:
        if df.empty:
            print("No face recognized.")
        else:
            print("Face recognized!")
            lst_recognizer.append(df)

            print(df['identity'])
            print(df['distance'])

# %%
counter = 0

lst_recognizer = []
# Initialize the webcam (0 is usually the default camera)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open the webcam.")
    exit()

print("Press 'C' to capture an image or 'Q' to quit.")

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Could not read frame from webcam.")
        break
        
    # Display the resulting frame
    cv2.imshow('Webcam', frame)

    # Wait for a key press
    key = cv2.waitKey(1) & 0xFF

    if key == ord('c'):
        cv2.imwrite("D:/Elecon/face_recognition_attendance_system/sample_data/test.jpeg" , frame)
        print("face number scanning " , counter)
        
        recognizerr("D:/Elecon/face_recognition_attendance_system/sample_data/test.jpeg")
    elif key == ord('q'):
        print("Exiting...")
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'C' to capture an image or 'Q' to quit.
# face number scanning  0
# D:/Elecon/face_recognition_attendance_system/sample_data/test.jpeg
# 25-01-15 09:58:21 - Searching D:/Elecon/face_recognition_attendance_system/sample_data/test.jpeg in 20 length datastore
# 25-01-15 09:58:23 - find function duration 2.1289708614349365 seconds
# Face recognized!
# 0     D:/Elecon/face_recognition_attendance_system/s...
# 1     D:/Elecon/face_recognition_attendance_system/s...
# 2     D:/Elecon/face_recognition_attendance_system/s...
# 3     D:/Elecon/face_recognition_attendance_system/s...
# 4     D:/Elecon/face_recognition_attendance_system/s...
# 5     D:/Elecon/face_recognition_attendance_system/s...
# 6     D:/Elecon/face_recognition_attendance_system/s...
# 7     D:/Elecon/face_recognition_attendance_system/s...
# 8     D:/Elecon/face_recognition_attendance_system/s...
# 9     D:/Elecon/face_recognition_attendance_system/s...
# 10    D:/Elecon/face_recognition_attendance_system/s...
# 11    D:/Elecon/face_recognition_attendance_system/s...
# Name: identity, dtype: object
# 0     0.243653
# 1     0.277931
# 2     0.340903
# 3     0.344668
# 4     0.393914
# 5     0.422954
# 6     0.448507
# 7     0.470561
# 8     0.475404
# 9     0.623549
# 10    0.623549
# 11    0.631910
# Name: distance, dtype: float64
# Exiting...

# %%
print(lst_recognizer)
# Out:
# [                                             identity  \
# 0   D:/Elecon/face_recognition_attendance_system/s...
# 1   D:/Elecon/face_recognition_attendance_system/s...
# 2   D:/Elecon/face_recognition_attendance_system/s...
# 3   D:/Elecon/face_recognition_attendance_system/s...
# 4   D:/Elecon/face_recognition_attendance_system/s...
# 5   D:/Elecon/face_recognition_attendance_system/s...
# 6   D:/Elecon/face_recognition_attendance_system/s...
# 7   D:/Elecon/face_recognition_attendance_system/s...
# 8   D:/Elecon/face_recognition_attendance_system/s...
# 9   D:/Elecon/face_recognition_attendance_system/s...
# 10  D:/Elecon/face_recognition_attendance_system/s...
# 11  D:/Elecon/face_recognition_attendance_system/s...
# 12  D:/Elecon/face_recognition_attendance_system/s...
# 13  D:/Elecon/face_recognition_attendance_system/s...
# 14  D:/Elecon/face_recognition_attendance_system/s...
# 15  D:/Elecon/face_recognition_attendance_system/s...
#
#                                         hash  target_x  target_y  target_w  \
# 0   12422e4b1130c05064b222579df87c7d145748c2       239       203       139
# 1   7759aaeafb422b54d23be7d1da73fd2fdff2b64f       262       246       104
# 2   5daf1723e49c3e8010e8437b0cace93627653391       236       192       136
# 3   77d931551f8a63e2c4879761eb951c7316126b47       242       224       141
# 4   bffcac775c8e04d253b9c7df39f4ed2347b89f95       262       194       131
# 5   5fecbe9e52b7ea133ac279b6f3aea2967d637c65       194       204       128
# 6   ce884dba76d2c12efede7c5fcf653f3967edb1fa       233       261        94
# 7   b634f79816ef688cfd5c19f5a470fbed2d851788       249       254        99
# 8   3d5d242ba99372f2eb059aa2f09cafa420451ca9       220       197       130
# 9   8518bbdc0038f86220812da299bba4fc89c39545       192       201       109
# 10  5f32370237cb0125536b6aa0a00d18278a6993a5       192       201       109
# 11  392731b56c75e6debff29c95277bec495a7783fb       203       234        94
# 12  3188fb5bb725cf1056a6c251152cb8a6b24243c2       218       265        84
# 13  40da5ad035bb7a661fafe0433aaaf84fd687cb70       285       198       131
# 14  85051d8910e549ae4462254dd73df809ca8438b9       285       198       131
# 15  6c90d4a7127936f6cfd70f8eeb9c73670829b75b       289       253       103
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
# 0        180       253       159       120       157       0.68  0.284777
# 1        133       253       159       120       157       0.68  0.293970
# 2        171       253       159       120       157       0.68  0.325617
# 3        180       253       159       120       157       0.68  0.348501
# 4        168       253       159       120       157       0.68  0.386388
# 5        173       253       159       120       157       0.68  0.414498
# 6        130       253       159       120       157       0.68  0.430638
# 7        127       253       159       120       157       0.68  0.484953
# 8        172       253       159       120       157       0.68  0.506063
# 9        167       253       159       120       157       0.68  0.535218
# 10       167       253       159       120       157       0.68  0.535218
# 11       140       253       159       120       157       0.68  0.552445
# 12       131       253       159       120       157       0.68  0.606032
# 13       171       253       159       120       157       0.68  0.659296
# 14       171       253       159       120       157       0.68  0.659296
# 15       133       253       159       120       157       0.68  0.672773  ,                                              identity  \
# 0   D:/Elecon/face_recognition_attendance_system/s...
# 1   D:/Elecon/face_recognition_attendance_system/s...
# 2   D:/Elecon/face_recognition_attendance_system/s...
# 3   D:/Elecon/face_recognition_attendance_system/s...
# 4   D:/Elecon/face_recognition_attendance_system/s...
# 5   D:/Elecon/face_recognition_attendance_system/s...
# 6   D:/Elecon/face_recognition_attendance_system/s...
# 7   D:/Elecon/face_recognition_attendance_system/s...
# 8   D:/Elecon/face_recognition_attendance_system/s...
# 9   D:/Elecon/face_recognition_attendance_system/s...
# 10  D:/Elecon/face_recognition_attendance_system/s...
# 11  D:/Elecon/face_recognition_attendance_system/s...
# 12  D:/Elecon/face_recognition_attendance_system/s...
#
#                                         hash  target_x  target_y  target_w  \
# 0   7759aaeafb422b54d23be7d1da73fd2fdff2b64f       262       246       104
# 1   12422e4b1130c05064b222579df87c7d145748c2       239       203       139
# 2   77d931551f8a63e2c4879761eb951c7316126b47       242       224       141
# 3   5daf1723e49c3e8010e8437b0cace93627653391       236       192       136
# 4   bffcac775c8e04d253b9c7df39f4ed2347b89f95       262       194       131
# 5   ce884dba76d2c12efede7c5fcf653f3967edb1fa       233       261        94
# 6   5fecbe9e52b7ea133ac279b6f3aea2967d637c65       194       204       128
# 7   b634f79816ef688cfd5c19f5a470fbed2d851788       249       254        99
# 8   3d5d242ba99372f2eb059aa2f09cafa420451ca9       220       197       130
# 9   8518bbdc0038f86220812da299bba4fc89c39545       192       201       109
# 10  5f32370237cb0125536b6aa0a00d18278a6993a5       192       201       109
# 11  392731b56c75e6debff29c95277bec495a7783fb       203       234        94
# 12  3188fb5bb725cf1056a6c251152cb8a6b24243c2       218       265        84
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
# 0        133       250       149       123       162       0.68  0.281426
# 1        180       250       149       123       162       0.68  0.310343
# 2        180       250       149       123       162       0.68  0.350595
# 3        171       250       149       123       162       0.68  0.356115
# 4        168       250       149       123       162       0.68  0.413000
# 5        130       250       149       123       162       0.68  0.432324
# 6        173       250       149       123       162       0.68  0.436809
# 7        127       250       149       123       162       0.68  0.462048
# 8        172       250       149       123       162       0.68  0.487796
# 9        167       250       149       123       162       0.68  0.551706
# 10       167       250       149       123       162       0.68  0.551706
# 11       140       250       149       123       162       0.68  0.577592
# 12       131       250       149       123       162       0.68  0.645640  ,                                              identity  \
# 0   D:/Elecon/face_recognition_attendance_system/s...
# 1   D:/Elecon/face_recognition_attendance_system/s...
# 2   D:/Elecon/face_recognition_attendance_system/s...
# 3   D:/Elecon/face_recognition_attendance_system/s...
# 4   D:/Elecon/face_recognition_attendance_system/s...
# 5   D:/Elecon/face_recognition_attendance_system/s...
# 6   D:/Elecon/face_recognition_attendance_system/s...
# 7   D:/Elecon/face_recognition_attendance_system/s...
# 8   D:/Elecon/face_recognition_attendance_system/s...
# 9   D:/Elecon/face_recognition_attendance_system/s...
# 10  D:/Elecon/face_recognition_attendance_system/s...
# 11  D:/Elecon/face_recognition_attendance_system/s...
# 12  D:/Elecon/face_recognition_attendance_system/s...
#
#                                         hash  target_x  target_y  target_w  \
# 0   7759aaeafb422b54d23be7d1da73fd2fdff2b64f       262       246       104
# 1   77d931551f8a63e2c4879761eb951c7316126b47       242       224       141
# 2   bffcac775c8e04d253b9c7df39f4ed2347b89f95       262       194       131
# 3   5daf1723e49c3e8010e8437b0cace93627653391       236       192       136
# 4   12422e4b1130c05064b222579df87c7d145748c2       239       203       139
# 5   5fecbe9e52b7ea133ac279b6f3aea2967d637c65       194       204       128
# 6   ce884dba76d2c12efede7c5fcf653f3967edb1fa       233       261        94
# 7   3d5d242ba99372f2eb059aa2f09cafa420451ca9       220       197       130
# 8   392731b56c75e6debff29c95277bec495a7783fb       203       234        94
# 9   8518bbdc0038f86220812da299bba4fc89c39545       192       201       109
# 10  5f32370237cb0125536b6aa0a00d18278a6993a5       192       201       109
# 11  b634f79816ef688cfd5c19f5a470fbed2d851788       249       254        99
# 12  3188fb5bb725cf1056a6c251152cb8a6b24243c2       218       265        84
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
# 0        133       256       141       124       166       0.68  0.346262
# 1        180       256       141       124       166       0.68  0.410143
# 2        168       256       141       124       166       0.68  0.415398
# 3        171       256       141       124       166       0.68  0.438067
# 4        180       256       141       124       166       0.68  0.467832
# 5        173       256       141       124       166       0.68  0.488828
# 6        130       256       141       124       166       0.68  0.492605
# 7        172       256       141       124       166       0.68  0.557474
# 8        140       256       141       124       166       0.68  0.558893
# 9        167       256       141       124       166       0.68  0.578321
# 10       167       256       141       124       166       0.68  0.578321
# 11       127       256       141       124       166       0.68  0.580852
# 12       131       256       141       124       166       0.68  0.673701  ,                                              identity  \
# 0   D:/Elecon/face_recognition_attendance_system/s...
# 1   D:/Elecon/face_recognition_attendance_system/s...
# 2   D:/Elecon/face_recognition_attendance_system/s...
# 3   D:/Elecon/face_recognition_attendance_system/s...
# 4   D:/Elecon/face_recognition_attendance_system/s...
# 5   D:/Elecon/face_recognition_attendance_system/s...
# 6   D:/Elecon/face_recognition_attendance_system/s...
# 7   D:/Elecon/face_recognition_attendance_system/s...
# 8   D:/Elecon/face_recognition_attendance_system/s...
# 9   D:/Elecon/face_recognition_attendance_system/s...
# 10  D:/Elecon/face_recognition_attendance_system/s...
# 11  D:/Elecon/face_recognition_attendance_system/s...
#
#                                         hash  target_x  target_y  target_w  \
# 0   77d931551f8a63e2c4879761eb951c7316126b47       242       224       141
# 1   12422e4b1130c05064b222579df87c7d145748c2       239       203       139
# 2   7759aaeafb422b54d23be7d1da73fd2fdff2b64f       262       246       104
# 3   bffcac775c8e04d253b9c7df39f4ed2347b89f95       262       194       131
# 4   5fecbe9e52b7ea133ac279b6f3aea2967d637c65       194       204       128
# 5   b634f79816ef688cfd5c19f5a470fbed2d851788       249       254        99
# 6   3d5d242ba99372f2eb059aa2f09cafa420451ca9       220       197       130
# 7   5daf1723e49c3e8010e8437b0cace93627653391       236       192       136
# 8   ce884dba76d2c12efede7c5fcf653f3967edb1fa       233       261        94
# 9   392731b56c75e6debff29c95277bec495a7783fb       203       234        94
# 10  8518bbdc0038f86220812da299bba4fc89c39545       192       201       109
# 11  5f32370237cb0125536b6aa0a00d18278a6993a5       192       201       109
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
# 0        180       240       189       121       159       0.68  0.419487
# 1        180       240       189       121       159       0.68  0.454230
# 2        133       240       189       121       159       0.68  0.516283
# 3        168       240       189       121       159       0.68  0.557447
# 4        173       240       189       121       159       0.68  0.567077
# 5        127       240       189       121       159       0.68  0.569122
# 6        172       240       189       121       159       0.68  0.575985
# 7        171       240       189       121       159       0.68  0.583820
# 8        130       240       189       121       159       0.68  0.592189
# 9        140       240       189       121       159       0.68  0.646883
# 10       167       240       189       121       159       0.68  0.667087
# 11       167       240       189       121       159       0.68  0.667087  ]

# %%
import cv2
import datetime

# Initialize the webcam (0 is usually the default camera)
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    print("Error: Could not open the webcam.")
    exit()

print("Press 'C' to capture an image or 'Q' to quit.")

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Could not read frame from webcam.")
        break

    # Display the resulting frame
    cv2.imshow('Webcam', frame)

    # Wait for a key press
    key = cv2.waitKey(1) & 0xFF

    if key == ord('c'):
        # Generate a unique filename using the current date and time
        timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f'./face_recognition_attendance_system/sample_data/new_Ronak/captured_image_{timestamp}.jpg'
        
        # Save the captured image
        cv2.imwrite(filename, frame)
        print(f"Image captured and saved as '{filename}'.")

    elif key == ord('q'):
        print("Exiting...")
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'C' to capture an image or 'Q' to quit.
# Image captured and saved as 'captured_image_20241223_092622.jpg'.
# Image captured and saved as 'captured_image_20241223_092625.jpg'.
# Image captured and saved as 'captured_image_20241223_092627.jpg'.
# Image captured and saved as 'captured_image_20241223_092628.jpg'.
# Image captured and saved as 'captured_image_20241223_092629.jpg'.
# Image captured and saved as 'captured_image_20241223_092630.jpg'.
# Image captured and saved as 'captured_image_20241223_092631.jpg'.
# Image captured and saved as 'captured_image_20241223_092632.jpg'.
# Image captured and saved as 'captured_image_20241223_092633.jpg'.
# Image captured and saved as 'captured_image_20241223_092634.jpg'.
# Image captured and saved as 'captured_image_20241223_092636.jpg'.
# Image captured and saved as 'captured_image_20241223_092637.jpg'.
# Image captured and saved as 'captured_image_20241223_092639.jpg'.
# Image captured and saved as 'captured_image_20241223_092640.jpg'.
# Image captured and saved as 'captured_image_20241223_092642.jpg'.
# Image captured and saved as 'captured_image_20241223_092642.jpg'.
# Image captured and saved as 'captured_image_20241223_092643.jpg'.
# Exiting...

# %%
# capture the image at the interval of 0.5 second automatically

# %%
import cv2
import time
import os

# Create a directory to store the captured images
output_dir = './sample_data/new_Ronak'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Initialize the webcam (0 is usually the default webcam)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Set the interval for capturing images in seconds
interval = 0.5  # Interval of 0.5 seconds

# Start capturing images
image_count = 0
while True:
    # Read a frame from the webcam
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Display the frame in a window (optional)
    cv2.imshow('Webcam', frame)

    # Save the captured frame as an image every 0.5 seconds
    if image_count % int(1 / interval) == 0:
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        image_name = f"{output_dir}/image_{timestamp}.jpg"
        cv2.imwrite(image_name, frame)
        print(f"Image saved as {image_name}")
    
    image_count += 1

    # Wait for the specified interval before capturing the next image
    time.sleep(interval)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Image saved as ./sample_data/new_Ronak/image_20250115_094053.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094054.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094055.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094056.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094057.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094058.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094059.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094100.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094101.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094102.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094103.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094104.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094105.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094106.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094107.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094108.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094109.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094110.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094111.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094112.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094113.jpg
# Image saved as ./sample_data/new_Ronak/image_20250115_094114.jpg
